# %% [markdown]
# # Step 2

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
data = pd.read_csv('pcaDF.csv')
features = data.drop('Status_Dead', axis=1)
labels = data['Status_Dead']
xTrain, xTest, yTrain, yTest = train_test_split(features, labels, test_size=0.3, random_state=42)

# %% [markdown]
# KNN

# %%
import math

def calculate_precision_recall(y_true, predictions):
    # For binary classification, we assume labels are 0 and 1
    tp = {0: 0, 1: 0}
    fp = {0: 0, 1: 0}
    fn = {0: 0, 1: 0}

    for true_label, predicted_label in zip(y_true, predictions):
        if true_label == predicted_label:
            tp[true_label] += 1
        else:
            fp[predicted_label] += 1
            fn[true_label] += 1

    precision = {}
    recall = {}
    for label in tp.keys():
        precision[label] = tp[label] / (tp[label] + fp[label]) if (tp[label] + fp[label]) else 0
        recall[label] = tp[label] / (tp[label] + fn[label]) if (tp[label] + fn[label]) else 0

    return precision, recall

def euclideanDistance(row1, row2):
    res = 0
    for i in range(len(row1)):
        res += (row1[i] - row2[i])**2
    return math.sqrt(res)

def getNeighbors(xTrain, yTrain, predictingPoint, numNeighbors):
    dist = []
    for i in range(len(xTrain)):
        dist.append((euclideanDistance(xTrain[i], predictingPoint),yTrain[i]))
    dist.sort(key=lambda x:x[0])
    return dist[0:numNeighbors]

def predict(xTrain, yTrain, testRow, numNeighbors):
    neighbors = getNeighbors(xTrain, yTrain, testRow, numNeighbors)
    count = {}
    for data, label in neighbors:
        count[label] = count.get(label,0) + 1
    max_label = max(count, key=count.get)
    return max_label

xTrain_list = xTrain.values.tolist()
xTest_list = xTest.values.tolist()
yTrain_list = yTrain.tolist()

# Predict and evaluate
predictions = [predict(xTrain_list, yTrain_list, test_instance, 3) for test_instance in xTest_list]
correct = 0
for prediction, true in zip(predictions, yTest):
    if prediction == true:
        correct += 1
accuracy_knn = correct / len(yTest)
print("Accuracy:", accuracy_knn)
# Calculate predictions
predictions = [predict(xTrain_list, yTrain_list, test_instance, 3) for test_instance in xTest_list]

# Calculate precision and recall
precision, recall = calculate_precision_recall(yTest.tolist(), predictions)

print("Precision:", precision)
print("Recall:", recall)
# Out:
# Accuracy: 0.8500459981600736
# Precision: {0: 0.8791208791208791, 1: 0.5116279069767442}
# Recall: {0: 0.9544468546637744, 1: 0.26666666666666666}

# %% [markdown]
# Naive Bayes

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score

model = GaussianNB()
model.fit(xTrain, yTrain)
predictions = model.predict(xTest)
accuracy_nb = accuracy_score(yTest, predictions)
precision_nb_0, precision_nb_1 = precision_score(yTest, predictions, average=None)
recall_nb_0, recall_nb_1 = recall_score(yTest, predictions, average=None)

print("Accuracy:", accuracy_nb)
print("Class 0 Precision:", precision_nb_0)
print("Class 1 Precision:", precision_nb_1)
print("Class 0 Recall:", recall_nb_0)
print("Class 1 Recall:", recall_nb_1)
# Out:
# Accuracy: 0.8104875804967802
# Class 0 Precision: 0.8874458874458875
# Class 1 Precision: 0.37423312883435583
# Class 0 Recall: 0.8893709327548807
# Class 1 Recall: 0.3696969696969697

# %% [markdown]
# Decision Tree

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

model = DecisionTreeClassifier(criterion='entropy', random_state=42)
model.fit(xTrain, yTrain)
predictions = model.predict(xTest)
accuracy_dt = accuracy_score(yTest, predictions)
precision_dt_0, precision_dt_1 = precision_score(yTest, predictions, average=None)
recall_dt_0, recall_dt_1 = recall_score(yTest, predictions, average=None)

print("Accuracy:", accuracy_dt)
print("Class 0 Precision:", precision_dt_0)
print("Class 1 Precision:", precision_dt_1)
print("Class 0 Recall:", recall_dt_0)
print("Class 1 Recall:", recall_dt_1)

# Get feature importances
feature_importances = model.feature_importances_

# Match feature importances with column names
feature_importance_dict = {feature: importance for feature, importance in zip(xTrain.columns, feature_importances)}

# Sort the features by most important first
sorted_feature_importances = sorted(feature_importance_dict.items(), key=lambda item: item[1], reverse=True)

print("\nFeature Importances:")
for feature, importance in sorted_feature_importances:
    print(f"{feature}: {importance}")
# Out:
# Accuracy: 0.812327506899724
# Class 0 Precision: 0.881104033970276
# Class 1 Precision: 0.36551724137931035
# Class 0 Recall: 0.9002169197396963
# Class 1 Recall: 0.3212121212121212
#
# Feature Importances:
# Principal Component 11: 0.17621369186765404
# Principal Component 6: 0.15111866932569387
# Principal Component 1: 0.10800294660755128
# Principal Component 10: 0.09734508958624896
# Principal Component 3: 0.09344399223982586
# Principal Component 7: 0.08403573912512356
# Principal Component 8: 0.07510330308397513
# Principal Component 9: 0.07256570861942346
# Principal Component 4: 0.06580149168025726
# Principal Component 2: 0.03844980646424669
# Principal Component 5: 0.0379195613999999

# %% [markdown]
# Random Forest

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
model = RandomForestClassifier(n_estimators=50, criterion='entropy', random_state=42)
model.fit(xTrain, yTrain)
predictions = model.predict(xTest)
accuracy_rf = accuracy_score(yTest, predictions)
precision_rf_0, precision_rf_1 = precision_score(yTest, predictions, average=None)
recall_rf_0, recall_rf_1 = recall_score(yTest, predictions, average=None)

# Printing out the results
print("Accuracy:", accuracy_rf)
print("Class 0 Precision:", precision_rf_0)
print("Class 1 Precision:", precision_rf_1)
print("Class 0 Recall:", recall_rf_0)
print("Class 1 Recall:", recall_rf_1)
# Out:
# Accuracy: 0.8564857405703772
# Class 0 Precision: 0.8799603174603174
# Class 1 Precision: 0.5569620253164557
# Class 0 Recall: 0.9620390455531453
# Class 1 Recall: 0.26666666666666666

# %% [markdown]
# GradientBoosting

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score

model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
model.fit(xTrain, yTrain)
predictions = model.predict(xTest)
accuracy_gb = accuracy_score(yTest, predictions)
precision_gb_0, precision_gb_1 = precision_score(yTest, predictions, average=None)
recall_gb_0, recall_gb_1 = recall_score(yTest, predictions, average=None)

print("Accuracy:", accuracy_gb)
print("Class 0 Precision:", precision_gb_0)
print("Class 1 Precision:", precision_gb_1)
print("Class 0 Recall:", recall_gb_0)
print("Class 1 Recall:", recall_gb_1)
# Out:
# Accuracy: 0.8574057037718491
# Class 0 Precision: 0.8748778103616813
# Class 1 Precision: 0.578125
# Class 0 Recall: 0.9707158351409978
# Class 1 Recall: 0.22424242424242424

# %% [markdown]
# # Step 3

# %%
import pandas as pd

# Define the parameter grid as a dictionary
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.001, 0.01, 0.1],
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 4, 6],
    'min_samples_leaf': [1, 2, 4]
}

# Create a DataFrame with 'Parameter' and 'Values' columns
df = pd.DataFrame(list(param_grid.items()), columns=['Parameter', 'Values'])

df
# Out:
#            Parameter              Values
# 0       n_estimators      [50, 100, 200]
# 1      learning_rate  [0.001, 0.01, 0.1]
# 2          max_depth           [3, 5, 7]
# 3  min_samples_split           [2, 4, 6]
# 4   min_samples_leaf           [1, 2, 4]

# %%
# Define the model
model = GradientBoostingClassifier(random_state=42)

# Create a dictionary of all values we want to test for n_estimators
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.001, 0.01, 0.1],
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 4, 6],
    'min_samples_leaf': [1, 2, 4]
}

# Use GridSearch
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, scoring='accuracy', verbose=2, n_jobs=2)
grid_search.fit(xTrain, yTrain)

# Print the best parameters and best score
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# Use the best parameters to make predictions
model = grid_search.best_estimator_
predictions = model.predict(xTest)
accuracy = accuracy_score(yTest, predictions)
print("Accuracy:", accuracy)
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.5s
# ...

# %% [markdown]
# run the following code on NYU HPC and copy past the results back

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
data = pd.read_csv('pcaDF.csv')
features = data.drop('Status_Dead', axis=1)
labels = data['Status_Dead']
xTrain, xTest, yTrain, yTest = train_test_split(features, labels, test_size=0.3, random_state=42)
model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
model.fit(xTrain, yTrain)
predictions = model.predict(xTest)

# Define the model
model = GradientBoostingClassifier(random_state=42)

# Create a dictionary of all values we want to test for n_estimators
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.001, 0.01, 0.1],
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 4, 6],
    'min_samples_leaf': [1, 2, 4]
}

# Use GridSearch
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, scoring='accuracy', verbose=2, n_jobs=2)
grid_search.fit(xTrain, yTrain)

# Print the best parameters and best score
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# Use the best parameters to make predictions
model1 = grid_search.best_estimator_
predictions_new = model1.predict(xTest)
# Calculate metrics
accuracy = accuracy_score(yTest, predictions_new)
precision = precision_score(yTest, predictions_new)
recall = recall_score(yTest, predictions_new)
f1 = f1_score(yTest, predictions_new)
conf_matrix = confusion_matrix(yTest, predictions_new)

# Display the metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)

# Additionally, display a comprehensive classification report
print("\nClassification Report:\n", classification_report(yTest, predictions_new))

# %% [markdown]
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.7s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.3s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   2.4s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   4.3s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   2.1s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   2.1s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.7s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.4s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   4.3s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   4.3s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=3, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.7s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.6s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=4, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=4, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   4.3s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   4.3s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   4.3s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=4, n_estimators=200; total time=   4.3s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=50; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=7, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   4.3s
#
# Best parameters: {'learning_rate': 0.01, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
#
# Best score: 0.8788468549314339
#
# Accuracy: 0.860165593376265
#
# Precision: 0.6585365853658537
#
# Recall: 0.16363636363636364
#
# F1 Score: 0.2621359223300971
#
# Confusion Matrix:
#  [[908  14]
#  [138  27]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.98      0.92       922
#          1.0       0.66      0.16      0.26       165
#
#     accuracy                           0.86      1087
#    macro avg       0.76      0.57      0.59      1087
# weighted avg       0.84      0.86      0.82      1087

# %%
# Define the metrics data as a dictionary
metrics_data = {
    'Best score': 0.8788468549314339,
    'Accuracy': 0.860165593376265,
    'Precision': 0.6585365853658537,
    'Recall': 0.16363636363636364,
    'F1 Score': 0.2621359223300971
}

# Create a DataFrame with 'Metrics' and 'Values' columns
metrics_df = pd.DataFrame(list(metrics_data.items()), columns=['Metric', 'Value'])

metrics_df
# Out:
#        Metric     Value
# 0  Best score  0.878847
# 1    Accuracy  0.860166
# 2   Precision  0.658537
# 3      Recall  0.163636
# 4    F1 Score  0.262136

# %%
# Define the classification report data
classification_report_data = {
    'Class': ['0.0', '1.0'],
    'Precision': [0.87, 0.66],
    'Recall': [0.98, 0.16],
    'F1-score': [0.92, 0.26],
    'Support': [922, 165]
}

# Create a DataFrame for the classification report
classification_report_df = pd.DataFrame(classification_report_data)

classification_report_df
# Out:
#   Class  Precision  Recall  F1-score  Support
# 0   0.0       0.87    0.98      0.92      922
# 1   1.0       0.66    0.16      0.26      165

# %% [markdown]
# Random Forest Grid Search

# %%
import pandas as pd

# Define the parameter grid as a dictionary
param_grid = {
     'n_estimators': [50, 100, 200],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}

# Create a DataFrame with 'Parameter' and 'Values' columns
df = pd.DataFrame(list(param_grid.items()), columns=['Parameter', 'Values'])

df
# Out:
#            Parameter              Values
# 0       n_estimators      [50, 100, 200]
# 1          criterion     [gini, entropy]
# 2          max_depth  [None, 10, 20, 30]
# 3  min_samples_split          [2, 5, 10]
# 4   min_samples_leaf           [1, 2, 4]
# 5       max_features        [sqrt, log2]

# %%
# Define the parameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}

# Use GridSearchCV to find the best parameters
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, scoring='accuracy', verbose=2, n_jobs=-1)
grid_search.fit(xTrain, yTrain)

# Print the best parameters and best score
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# Use the best parameters to make predictions
model = grid_search.best_estimator_
predictions = model.predict(xTest)
# Calculate metrics
accuracy = accuracy_score(yTest, predictions)
precision = precision_score(yTest, predictions)
recall = recall_score(yTest, predictions)
f1 = f1_score(yTest, predictions)
conf_matrix = confusion_matrix(yTest, predictions)

# Display the metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion Matrix:\n", conf_matrix)

# Additionally, display a comprehensive classification report
print("\nClassification Report:\n", classification_report(yTest, predictions))
# Out:
# Fitting 3 folds for each of 432 candidates, totalling 1296 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 13
#      11 # Use GridSearchCV to find the best parameters
#      12 grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, scoring='accuracy', verbose=2, n_jobs=-1)
# ---> 13 grid_search.fit(xTrain, yTrain)
#      15 # Print the best parameters and best score
#      16 print("Best parameters:", grid_search.best_params_)
#
# File c:\Program Files\Python311\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# ...

# %% [markdown]
# Copy paste the following output from running the code above in HPC

# %% [markdown]
# Accuracy: 0.8528058877644894
# Fitting 3 folds for each of 432 candidates, totalling 1296 fits
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
#
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.9s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.9s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.9s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.9s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.9s
#
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.4s
#
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.9s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.9s
#
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.9s
#
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.9s
#
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.9s
#
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.4s
#
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.4s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.7s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.7s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.7s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.7s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.9s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.9s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.9s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.9s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.3s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.3s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.3s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.5s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.6s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.2s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.1s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.8s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.7s
#
# [CV] END criterion=entropy, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.6s
#
# Best parameters: {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
#
# Best score: 0.8808187741290183
#
# Accuracy: 0.858325666973321
#
# Precision: 0.5753424657534246
#
# Recall: 0.2545454545454545
#
# F1 Score: 0.35294117647058826
#
# Confusion Matrix:
#  [[891  31]
#  [123  42]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.97      0.92       922
#          1.0       0.58      0.25      0.35       165
#
#     accuracy                           0.86      1087
#    macro avg       0.73      0.61      0.64      1087
# weighted avg       0.83      0.86      0.83      1087

# %%
# Define the metrics data as a dictionary
metrics_data = {
    'Best score': 0.8808187741290183,
    'Accuracy': 0.858325666973321,
    'Precision': 0.5753424657534246,
    'Recall': 0.2545454545454545,
    'F1 Score': 0.35294117647058826
}

# Create a DataFrame with 'Metrics' and 'Values' columns
metrics_df = pd.DataFrame(list(metrics_data.items()), columns=['Metric', 'Value'])

metrics_df
# Out:
#        Metric     Value
# 0  Best score  0.880819
# 1    Accuracy  0.858326
# 2   Precision  0.575342
# 3      Recall  0.254545
# 4    F1 Score  0.352941

# %% [markdown]
# random forest using best hyperparameter

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score 

model = RandomForestClassifier(n_estimators=100, criterion='entropy', random_state=42, max_depth=20, min_samples_split=2, min_samples_leaf=5, max_features='sqrt')
model.fit(xTrain, yTrain)
predictions = model.predict(xTest)
accuracy_rf = accuracy_score(yTest, predictions)

precision_rf_0, precision_rf_1 = precision_score(yTest, predictions, average=None)
recall_rf_0, recall_rf_1 = recall_score(yTest, predictions, average=None)

# Printing out the results
print("Accuracy:", accuracy_rf)
print("Class 0 Precision:", precision_rf_0)
print("Class 1 Precision:", precision_rf_1)
print("Class 0 Recall:", recall_rf_0)
print("Class 1 Recall:", recall_rf_1)

# Get feature importances
feature_importances = model.feature_importances_

# Match feature importances with column names
feature_importance_dict = {feature: importance for feature, importance in zip(xTrain.columns, feature_importances)}

# Sort the features by most important first
sorted_feature_importances = sorted(feature_importance_dict.items(), key=lambda item: item[1], reverse=True)

print("\nFeature Importances:")
for feature, importance in sorted_feature_importances:
    print(f"{feature}: {importance}")
# Out:
# Accuracy: 0.860165593376265
# Class 0 Precision: 0.8774509803921569
# Class 1 Precision: 0.5970149253731343
# Class 0 Recall: 0.9707158351409978
# Class 1 Recall: 0.24242424242424243
#
# Feature Importances:
# Principal Component 11: 0.17866426100964386
# Principal Component 6: 0.11952689142286832
# Principal Component 1: 0.09893340860104934
# Principal Component 8: 0.09619015443873119
# Principal Component 9: 0.0792838876914408
# Principal Component 7: 0.07883173176677777
# Principal Component 4: 0.07564737846373906
# Principal Component 10: 0.07311772133671776
# Principal Component 3: 0.07175430213293979
# Principal Component 2: 0.06600774003575208
# Principal Component 5: 0.06204252310033997

# %% [markdown]
# Gradient boosting using the best hyperparameter Best parameters: {'learning_rate': 0.01, 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

model = GradientBoostingClassifier(n_estimators=200, learning_rate=0.01, random_state=42, max_depth=3, min_samples_split=2, min_samples_leaf=1)
model.fit(xTrain, yTrain)
predictions = model.predict(xTest)
accuracy_gb = accuracy_score(yTest, predictions)
precision_gb_0, precision_gb_1 = precision_score(yTest, predictions, average=None)
recall_gb_0, recall_gb_1 = recall_score(yTest, predictions, average=None)

print("Accuracy:", accuracy_gb)
print("Class 0 Precision:", precision_gb_0)
print("Class 1 Precision:", precision_gb_1)
print("Class 0 Recall:", recall_gb_0)
print("Class 1 Recall:", recall_gb_1)

# Get feature importances
feature_importances = model.feature_importances_

# Match feature importances with column names
feature_importance_dict = {feature: importance for feature, importance in zip(xTrain.columns, feature_importances)}

# Sort the features by most important first
sorted_feature_importances = sorted(feature_importance_dict.items(), key=lambda item: item[1], reverse=True)

print("\nFeature Importances:")
for feature, importance in sorted_feature_importances:
    print(f"{feature}: {importance}")
# Out:
# Accuracy: 0.860165593376265
# Class 0 Precision: 0.8680688336520076
# Class 1 Precision: 0.6585365853658537
# Class 0 Recall: 0.9848156182212582
# Class 1 Recall: 0.16363636363636364
#
# Feature Importances:
# Principal Component 11: 0.2924362523192813
# Principal Component 6: 0.2620777359544723
# Principal Component 1: 0.15780099905366626
# Principal Component 7: 0.07504637096310152
# Principal Component 9: 0.06151061610579975
# Principal Component 8: 0.044840791791733295
# Principal Component 3: 0.03517818301573433
# Principal Component 4: 0.02274276896980848
# Principal Component 10: 0.021734595726582404
# Principal Component 2: 0.018657405152025512
# Principal Component 5: 0.00797428094779483

# %% [markdown]
# # Step 4

# %%
import pandas as pd

# Define the data for each classification technique as provided in the image
data = {
    'K-Nearest Neighbors': {'Accuracy': accuracy_knn, 'Precision_0': precision[0], 'Recall_0': recall[0], 'Precision_1': precision[1], 'Recall_1': recall[1]},
    'Naive Bayes': {'Accuracy': accuracy_nb, 'Precision_0': precision_nb_0, 'Recall_0': recall_nb_0, 'Precision_1': precision_nb_1, 'Recall_1': recall_nb_1},  # Missing 'Recall_0' added as None
    'C4.5 Decision Tree': {'Accuracy': accuracy_dt, 'Precision_0': precision_dt_0, 'Recall_0': recall_dt_0, 'Precision_1': precision_dt_1, 'Recall_1': recall_dt_1},
    'Random Forest': {'Accuracy': accuracy_rf, 'Precision_0':precision_rf_0, 'Recall_0': recall_rf_0, 'Precision_1': precision_rf_1, 'Recall_1': recall_rf_1},
    'Gradient Boosting': {'Accuracy': accuracy_gb, 'Precision_0': precision_gb_0, 'Recall_0': recall_gb_0, 'Precision_1': precision_gb_1, 'Recall_1': recall_gb_1}
}

# Create a DataFrame from the data dictionary
# The keys of the dictionary become the index of the DataFrame
df = pd.DataFrame(data).transpose()

# Let's take a look at the DataFrame to confirm it's correctly organized
df
# Out:
#                      Accuracy  Precision_0  Recall_0  Precision_1  Recall_1
# K-Nearest Neighbors  0.850046     0.879121  0.954447     0.511628  0.266667
# Naive Bayes          0.810488     0.887446  0.889371     0.374233  0.369697
# C4.5 Decision Tree   0.812328     0.881104  0.900217     0.365517  0.321212
# Random Forest        0.860166     0.877451  0.970716     0.597015  0.242424
# Gradient Boosting    0.860166     0.868069  0.984816     0.658537  0.163636
